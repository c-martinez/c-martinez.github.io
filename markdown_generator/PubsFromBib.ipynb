# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a set of bibtex of publications and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)).
#
# The core python code is also in `pubsFromBibs.py`.
# Run either from the `markdown_generator` folder after replacing updating the publist dictionary with:
# * bib file names
# * specific venue keys based on your bib file preferences
# * any specific pre-text for specific files
# * Collection Name (future feature)
#
# TODO: Make this work with other databases of citations,
# TODO: Merge this with the existing TSV parsing solution

# %%
from pybtex.database.input import bibtex
import pybtex.database.input.bibtex 
from time import strptime
import string
import html
import os
import re

# %%
#todo: incorporate different collection types rather than a catch all publications, requires other changes to template
publist = {
    "journal":{
        "file": "pubs.bib",
        "venuekey" : "publisher",
        "venue-pretext" : "",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
    } 
}

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %%
for pubsource in publist:
    parser = bibtex.Parser()
    bibdata = parser.parse_file(publist[pubsource]["file"])

    #loop through the individual references in a given bibtex file
    for bib_id in bibdata.entries:
        #reset default date
        pub_year = "1900"
        pub_month = "01"
        pub_day = "01"
        
        b = bibdata.entries[bib_id].fields
        
        try:
            pub_year = f'{b["year"]}'

            #todo: this hack for month and day needs some cleanup
            if "month" in b.keys(): 
                if(len(b["month"])<3):
                    pub_month = "0"+b["month"]
                    pub_month = pub_month[-2:]
                elif(b["month"] not in range(12)):
                    tmnth = strptime(b["month"][:3],'%b').tm_mon   
                    pub_month = "{:02d}".format(tmnth) 
                else:
                    pub_month = str(b["month"])
            if "day" in b.keys(): 
                pub_day = str(b["day"])

                
            pub_date = pub_year+"-"+pub_month+"-"+pub_day
            
            #strip out {} as needed (some bibtex entries that maintain formatting)
            clean_title = b["title"].replace("{", "").replace("}","").replace("\\","").replace(" ","-")    

            url_slug = re.sub("\\[.*\\]|[^a-zA-Z0-9_-]", "", clean_title)
            url_slug = url_slug.replace("--","-")

            md_filename = (str(pub_date) + "-" + url_slug + ".md").replace("--","-")
            html_filename = (str(pub_date) + "-" + url_slug).replace("--","-")

            #Build Citation from text
            citation = ""

            #citation authors - todo - add highlighting for primary author?
            for author in bibdata.entries[bib_id].persons["author"]:
                try:
                    citation = citation+" "+author.first_names[0]+" "+author.last_names[0]+", "
                except:
                    # accidentally dropping an author
                    print(f'WARNING dropping author {author} from entry {bib_id}...')

            #citation title
            citation = citation + "\"" + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + ".\""

            #add venue logic depending on citation type
            venue = publist[pubsource]["venue-pretext"]+b[publist[pubsource]["venuekey"]].replace("{", "").replace("}","").replace("\\","")

            citation = citation + " " + html_escape(venue)
            citation = citation + ", " + pub_year + "."

            # Category is the entry type
            category = bibdata.entries[bib_id].type
            
            ## YAML variables
            md = "---\ntitle: \""   + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + '"\n'
            
            md += """collection: """ +  publist[pubsource]["collection"]["name"]

            md += """\ncategory: """ +  category

            md += """\npermalink: """ + publist[pubsource]["collection"]["permalink"]  + html_filename
            
            note = False
            if "note" in b.keys():
                if len(str(b["note"])) > 5:
                    md += "\nexcerpt: '" + html_escape(b["note"]) + "'"
                    note = True

            md += "\ndate: " + str(pub_date) 

            md += "\nvenue: '" + html_escape(venue) + "'"
            
            url = False
            if "url" in b.keys():
                if len(str(b["url"])) > 5:
                    md += "\npaperurl: '" + b["url"] + "'"
                    url = True

            md += "\ncitation: '" + html_escape(citation) + "'"

            md += "\n---"

            
            ## Markdown description for individual page
            if note:
                md += "\n" + html_escape(b["note"]) + "\n"

            if url:
                md += "\n[Access paper here](" + b["url"] + "){:target=\"_blank\"}\n" 
            else:
                md += "\nUse [Google Scholar](https://scholar.google.com/scholar?q="+html.escape(clean_title.replace("-","+"))+"){:target=\"_blank\"} for full citation"

            md_filename = os.path.basename(md_filename)

            with open("../_publications/" + md_filename, 'w', encoding="utf-8") as f:
                f.write(md)
            print(f'SUCESSFULLY PARSED {bib_id}: \"', b["title"][:60],"..."*(len(b['title'])>60),"\"")
        # field may not exist for a reference
        except KeyError as e:
            print(f'WARNING Missing Expected Field {e} from entry {bib_id}: \"', b["title"][:30],"..."*(len(b['title'])>30),"\"")
            continue
# Out:
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.13740998: " Developing and Aligning Policies on Research Software: Recom ... "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.8356278: " Cite.Software  "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.8297630: " Software sustainability  "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.8187798: " grlc: the git repository linked data API constructor  "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.8093501: " How do software management plans advance open science and co ... "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.8096612: " RDA TIGER D3.1 OS Landscape analysis and potential engagemen ... "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.8020325: " FAIR Software for the Social Sciences  "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.7951155: " Report on the Workshop on Sustainable Software Sustainabilit ... "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.7671294: " pbg-ld  "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.7589725: " Practical guide to Software Management Plans  "
# SUCESSFULLY PARSED https://doi.org/10.15497/rda00089: " RDA for FAIR Data, Software and Hardware Community Cross-fer ... "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.7384410: " Global gathering of research software funders sets the agend ... "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.7350528: " Software Horror Escape Room: Publish or Purrrish  "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.6375540: " A Survey on Adoption Guidelines for the FAIR4RS Principles:  ... "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.6366575: " howfairis-github-action  "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.6340732: " The Overlap Between FAIR for Research Software and Open Scie ... "
# SUCESSFULLY PARSED Sochat_2022: " The Research Software Encyclopedia: A Community Framework to ... "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.6258366: " FAIR4RS: Adoption support  "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.5524726: " RDA Webinar: FAIR Principles for Research Software (FAIR4RS  ... "
# SUCESSFULLY PARSED Mero_o_Pe_uela_2021: " Web Data {APIs} for Knowledge Graphs: Easing Access to Seman ... "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.5504016: " Defining Research Software: a controversial discussion  "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.5211222: " FAIR Workflows Data publishing of scientific protocols  "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.5046189: " FAIR Software Route Landscaping  "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.5116050: " FAIR for Research Software, Machine Learning Models, and Wor ... "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.6637920: " FAIR4RS community consultation May 2021  "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.4923124: " FAIR Research Software and Science Gateways  "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.4635410: " FAIR4RS WG subgroup community consultation March 2021  "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.4623713: " Professionalising data stewardship in the Netherlands. Compe ... "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.4561864: " CINECA webinar: FAIR software tools  "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.4560056: " Research and Software Engineering at the Netherlands eScienc ... "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.4552004: " How FAIR is your research software?  "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.4551990: " Why do we need an EuSSI?  "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.4538888: " pbg-ld queries  "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.4529129: " A first Introduction to Open Science  "
# SUCESSFULLY PARSED https://doi.org/10.15497/rda00065: " FAIR Principles for Research Software (FAIR4RS Principles)  "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.4310217: " Five recommendations for "FAIR software"  "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.4355231: " SORSE2020 outputs for the FAIR4RS workshop  "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.4312682: " howfairis  "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.4293274: " Answers to five questions about FAIR data  "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.4059590: " FAIR Data Point  "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.4020622: " Netherlands eScience Center - Software Development Guide  "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.4017710: " badge  "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.4015123: " A vision for supporting research software sustainability acr ... "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.4015242: " Raising the Profile of Research Software: Recommendations fo ... "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.4430813: " What do we (not) know about RSE?  "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.3922155: " Report on the Workshop on Sustainable Software Sustainabilit ... "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.3903257: " A Collection of Open Science Use Cases  "
# SUCESSFULLY PARSED app10196813: " Linked Data Platform for Solanaceae Species  "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.3378572: " Raising the Profile of Research Software  "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.2647436: " Making Research Software a First-Class Citizen in Research  "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.2647461: " Towards sustainable training in essential computing research ... "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.2203851: " Linked Data Platform for Plant Breeding and Genomics  "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.1494141: " Time shifting word2vec models from Times  "
# SUCESSFULLY PARSED https://doi.org/10.5281/zenodo.1436404: " BeyondTheBook  "
